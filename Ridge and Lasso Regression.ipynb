# %% [markdown]
# # Aprendizaje Automático Aplicado

# %% [markdown]
# ## Modelo de regresión Ridge y Lasso
#
# Utilizando scikit-learn con diferentes tipos de escalado  (StandardScaler, MinMaxScaler, RobustScaler).
#
# Conjunto de datos de "California Housing" disponible en la URL siguiente: https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/housing/housing.csv

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Load dataset
url = "https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/housing/housing.csv"
df = pd.read_csv(url)

# Drop rows with NaN values
df.dropna(inplace=True)

# Convert categorical feature "Ocean_proximity" to numerical
df['ocean_proximity'] = df['ocean_proximity'].astype('category')
df['ocean_proximity'] = df['ocean_proximity'].cat.codes

# Prepare data for modeling
X = df.drop("median_house_value", axis=1)
y = df["median_house_value"]

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Define list of alphas to test
alphas = [0.1, 1, 10, 100, 1000]

# Scale data using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train and evaluate Ridge models with different alphas
r2_train_scores = []
r2_test_scores = []
for alpha in alphas:
    ridge = Ridge(alpha=alpha)
    ridge.fit(X_train_scaled, y_train)
    r2_train_scores.append(ridge.score(X_train_scaled, y_train))
    r2_test_scores.append(ridge.score(X_test_scaled, y_test))

# Plot results of Ridge models with StandardScaler
plt.plot(alphas, r2_train_scores, label="Train R2")
plt.plot(alphas, r2_test_scores, label="Test R2")
plt.xscale("log")
plt.xlabel("Alpha")
plt.ylabel("R2")
plt.title("Ridge Regression with StandardScaler")
plt.legend()
plt.show()

# Scale data using MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train and evaluate Ridge models with different alphas
r2_train_scores = []
r2_test_scores = []
for alpha in alphas:
    ridge = Ridge(alpha=alpha)
    ridge.fit(X_train_scaled, y_train)
    r2_train_scores.append(ridge.score(X_train_scaled, y_train))
    r2_test_scores.append(ridge.score(X_test_scaled, y_test))

# Plot results of Ridge models with StandardScaler
plt.plot(alphas, r2_train_scores, label="Train R2")
plt.plot(alphas, r2_test_scores, label="Test R2")
plt.xscale("log")
plt.xlabel("Alpha")
plt.ylabel("R2")
plt.title("Ridge Regression with MinMaxScaler")
plt.legend()
plt.show()

# Scale data using RobustScaler
scaler = RobustScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train and evaluate Ridge models with different alphas
r2_train_scores = []
r2_test_scores = []
for alpha in alphas:
    ridge = Ridge(alpha=alpha)
    ridge.fit(X_train_scaled, y_train)
    r2_train_scores.append(ridge.score(X_train_scaled, y_train))
    r2_test_scores.append(ridge.score(X_test_scaled, y_test))

# Plot results of Ridge models with StandardScaler
plt.plot(alphas, r2_train_scores, label="Train R2")
plt.plot(alphas, r2_test_scores, label="Test R2")
plt.xscale("log")
plt.xlabel("Alpha")
plt.ylabel("R2")
plt.title("Ridge Regression with RobustScaler")
plt.legend()
plt.show()
